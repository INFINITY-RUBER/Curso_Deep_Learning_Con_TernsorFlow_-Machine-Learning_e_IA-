# %% [markdown]
# <a href="https://colab.research.google.com/github/INFINITY-RUBER/Curso_Deep_Learning_Con_TernsorFlow_Machine-Learning_e_IA-/blob/master/scripts/tema08/03-skip-grams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install tensorflow==1.14

# %% [markdown]
# # Bag of Words Contínuo o Skip Gramas

# %% [markdown]
# - King - man + woman = Queen
# - Indian Pale Ale - hops + malt = Stout

# %% [markdown]
# - Si queremos predecir una palabra objetivo a partir de un contexto (palabras que la rodean): Continuous Bag of Words
# - Si queremos predecir las palabras que rodean (contexto) a una palabra objetivo: Skip-Grama

# %% [markdown]
# ## Descarga de datos

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import string
import requests
import collections
import io
import tarfile
import urllib.request
import nltk
from nltk.corpus import stopwords
session = tf.Session()

# %%
batch_size = 50
embedding_size = 200
vocabulary_size = 10000
generations = 50000
print_loss_every = 500
num_sampled = int(batch_size/2)
window_size = 2
nltk.download('stopwords')
stops = stopwords.words('english')
print_valid_every = 2000
valid_words = ['cliche', 'love', 'hate', 'silly', 'sad']
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stops

# %%
def load_movies_data():
    save_folder_name = "../../datasets/movies_data"
    pos_file = os.path.join(save_folder_name, 'rt-polarity.pos')
    neg_file = os.path.join(save_folder_name, 'rt-polarity.neg')
    
    if os.path.exists(save_folder_name):
        ## Podemos cargar la info directamente desde el PC
        pos_data = []
        with open(pos_file, 'r') as temp_pos_file:
            for row in temp_pos_file:
                pos_data.append(row)
                
        neg_data = []
        with open(neg_file, 'r') as temp_neg_file:
            for row in temp_neg_file:
                neg_data.append(row)
        
    else:
        ## Debemos descargar los ficheros de internet y guardarlos en esta carpeta
        url = "http://www.cs.cornell.edu/people/pabo/movie-review-data/rt-polaritydata.tar.gz"
        stream_data = urllib.request.urlopen(url)
        tmp = io.BytesIO()
        while True:
            s = stream_data.read(16384)
            if not s: 
                break
            tmp.write(s)
        stream_data.close()
        tmp.seek(0)
        
        tar_file = tarfile.open(fileobj=tmp, mode='r:gz')
        pos = tar_file.extractfile('rt-polaritydata/rt-polarity.pos')
        neg = tar_file.extractfile('rt-polaritydata/rt-polarity.neg')
        
        pos_data = []
        for line in pos:
            pos_data.append(line.decode('ISO-8859-1').encode('ascii', errors='ignore').decode())
            
        neg_data = []
        for line in neg:
            neg_data.append(line.decode('ISO-8859-1').encode('ascii', errors='ignore').decode())
            
        tar_file.close()
        
        if not os.path.exists(save_folder_name):
            os.makedirs(save_folder_name)
        with open(pos_file, 'w') as pos_file_handler:
            pos_file_handler.write(''.join(pos_data))
        with open(neg_file, 'w') as neg_file_handler:
            neg_file_handler.write(''.join(neg_data))
    
    texts = pos_data + neg_data
    target = [1]*len(pos_data) + [0]*len(neg_data)
    return (texts, target)

# %%
texts, target = load_movies_data()

# %%
tes =texts[0:8]
print(tes)
tes = [x.lower() for x in tes]# paso a minusculas
tes = [''.join(c for c in x if c not in string.punctuation) for x in tes]# elimino los putos y signos de esclamacion
print(tes)
tes = [''.join(c for c in x if c not in '0123456789') for x in tes]# elimina los numeros
print(tes)
tes = [' '.join(word for word in x.split() if word not in (stops)) for x in tes]# elimino las stop
print(tes)
tes = [' '.join(x.split()) for x in tes]
print(tes)
tar = [target[ix] for ix, x in enumerate(tes) if len(x.split())>2]
print(tar)
# Out:
# ['rock destined st centurys new conan hes going make splash even greater arnold schwarzenegger jeanclaud van damme steven segal', 'gorgeously elaborate continuation lord rings trilogy huge column words cannot adequately describe cowriterdirector peter jacksons expanded vision j r r tolkiens middleearth', 'effective tootepid biopic', 'sometimes like go movies fun wasabi good place start', 'emerges something rare issue movie thats honest keenly observed doesnt feel like one', 'film provides great insight neurotic mindset comics even reached absolute top game', 'offers rare combination entertainment education', 'perhaps picture ever made literally showed road hell paved good intentions']
# ['rock destined st centurys new conan hes going make splash even greater arnold schwarzenegger jeanclaud van damme steven segal', 'gorgeously elaborate continuation lord rings trilogy huge column words cannot adequately describe cowriterdirector peter jacksons expanded vision j r r tolkiens middleearth', 'effective tootepid biopic', 'sometimes like go movies fun wasabi good place start', 'emerges something rare issue movie thats honest keenly observed doesnt feel like one', 'film provides great insight neurotic mindset comics even reached absolute top game', 'offers rare combination entertainment education', 'perhaps picture ever made literally showed road hell paved good intentions']
# ['rock destined st centurys new conan hes going make splash even greater arnold schwarzenegger jeanclaud van damme steven segal', 'gorgeously elaborate continuation lord rings trilogy huge column words cannot adequately describe cowriterdirector peter jacksons expanded vision j r r tolkiens middleearth', 'effective tootepid biopic', 'sometimes like go movies fun wasabi good place start', 'emerges something rare issue movie thats honest keenly observed doesnt feel like one', 'film provides great insight neurotic mindset comics even reached absolute top game', 'offers rare combination entertainment education', 'perhaps picture ever made literally showed road hell paved good intentions']
# ['rock destined st centurys new conan hes going make splash even greater arnold schwarzenegger jeanclaud van damme steven segal', 'gorgeously elaborate continuation lord rings trilogy huge column words cannot adequately describe cowriterdirector peter jacksons expanded vision j r r tolkiens middleearth', 'effective tootepid biopic', 'sometimes like go movies fun wasabi good place start', 'emerges something rare issue movie thats honest keenly observed doesnt feel like one', 'film provides great insight neurotic mindset comics even reached absolute top game', 'offers rare combination entertainment education', 'perhaps picture ever made literally showed road hell paved good intentions']
# ['rock destined st centurys new conan hes going make splash even greater arnold schwarzenegger jeanclaud van damme steven segal', 'gorgeously elaborate continuation lord rings trilogy huge column words cannot adequately describe cowriterdirector peter jacksons expanded vision j r r tolkiens middleearth', 'effective tootepid biopic', 'sometimes like go movies fun wasabi good place start', 'emerges something rare issue movie thats honest keenly observed doesnt feel like one', 'film provides great insight neurotic mindset comics even reached absolute top game', 'offers rare combination entertainment education', 'perhaps picture ever made literally showed road hell paved good intentions']
# [1, 1, 1, 1, 1, 1, 1, 1]

# %%
target[0:3]
# Out:
# [1, 1, 1]

# %% [markdown]
# ## Limpieza de datos

# %%
def normalize_text(texts, stops):
    texts = [x.lower() for x in texts]# paso a minusculas
    texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]# elimino los putos y signos de esclamacion
    texts = [''.join(c for c in x if c not in '0123456789') for x in texts]# elimina los numeros
    texts = [' '.join(word for word in x.split() if word not in (stops)) for x in texts]# elimino las stop
    texts = [' '.join(x.split()) for x in texts]
    return texts

# %%
texts = normalize_text(texts, stops)

# %%
texts[0]
# Out:
# 'rock destined st centurys new conan hes going make splash even greater arnold schwarzenegger jeanclaud van damme steven segal'

# %%
len(texts)
# Out:
# 10406

# %%
target = [target[ix] for ix, x in enumerate(texts) if len(x.split())>2]
texts = [x for x in texts if len(x.split())>2]

# %%
len(texts)
# Out:
# 10406

# %%
def build_dictionary(sentences, vocabulary_size):
    split_sentences = [s.split() for s in sentences]
    words = [x for sublist in split_sentences for x in sublist]
    count = [['RARE', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))# nos da las palabras mas frecuentes del dicionario
    word_dict = {}
    for word, word_count in count:
        word_dict[word] = len(word_dict)
    return word_dict

# %%
word_dict = build_dictionary(texts, vocabulary_size)

# %%
word_dict
# Out:
# {'RARE': 0,
#  'film': 1,
#  'movie': 2,
#  'one': 3,
#  'like': 4,
#  'story': 5,
#  'much': 6,
#  'even': 7,
#  'good': 8,
#  'comedy': 9,
#  'time': 10,
#  'characters': 11,
#  'films': 12,
#  'little': 13,
#  'way': 14,
#  'funny': 15,
#  'make': 16,
#  'movies': 17,
#  'enough': 18,
#  'never': 19,
#  'makes': 20,
#  'may': 21,
#  'us': 22,
#  'best': 23,
#  'work': 24,
#  'director': 25,
#  'doesnt': 26,
#  'bad': 27,
#  'love': 28,
#  'life': 29,
#  'would': 30,
#  'theres': 31,
#  'well': 32,
#  'new': 33,
#  'could': 34,
#  'something': 35,
#  'really': 36,
#  'made': 37,
#  'performances': 38,
#  'thats': 39,
#  'many': 40,
#  'drama': 41,
#  'look': 42,
#  'plot': 43,
#  'still': 44,
#  'see': 45,
#  'isnt': 46,
#  'every': 47,
#  'two': 48,
#  'nothing': 49,
#  'people': 50,
#  'better': 51,
#  'long': 52,
#  'without': 53,
#  'get': 54,
#  'action': 55,
#  'fun': 56,
#  'great': 57,
#  'though': 58,
#  'might': 59,
#  'big': 60,
#  'also': 61,
#  'cast': 62,
#  'another': 63,
#  'ever': 64,
#  'kind': 65,
#  'first': 66,
#  'audience': 67,
#  'humor': 68,
#  'sense': 69,
#  'character': 70,
#  'performance': 71,
#  'dont': 72,
#  'feels': 73,
#  'script': 74,
#  'far': 75,
#  'less': 76,
#  'seems': 77,
#  'often': 78,
#  'thing': 79,
#  'minutes': 80,
#  'real': 81,
#  'feel': 82,
#  'picture': 83,
#  'world': 84,
#  'almost': 85,
#  'tale': 86,
#  'cant': 87,
#  'yet': 88,
#  'thriller': 89,
#  'quite': 90,
#  'interesting': 91,
#  'documentary': 92,
#  'years': 93,
#  'youre': 94,
#  'screen': 95,
#  'rather': 96,
#  'entertaining': 97,
#  'end': 98,
#  'hollywood': 99,
#  'take': 100,
#  'de': 101,
#  'watching': 102,
#  'seen': 103,
#  'go': 104,
#  'ultimately': 105,
#  'full': 106,
#  'hard': 107,
#  'heart': 108,
#  'comes': 109,
#  'romantic': 110,
#  'moments': 111,
#  'despite': 112,
#  'lot': 113,
#  'american': 114,
#  'actors': 115,
#  'old': 116,
#  'acting': 117,
#  'family': 118,
#  'original': 119,
#  'right': 120,
#  'find': 121,
#  'things': 122,
#  'worth': 123,
#  'gets': 124,
#  'human': 125,
#  'takes': 126,
#  'times': 127,
#  'come': 128,
#  'back': 129,
#  'dialogue': 130,
#  'watch': 131,
#  'man': 132,
#  'scenes': 133,
#  'material': 134,
#  'young': 135,
#  'kids': 136,
#  'compelling': 137,
#  'music': 138,
#  'anyone': 139,
#  'think': 140,
#  'works': 141,
#  'seem': 142,
#  'emotional': 143,
#  'want': 144,
#  'gives': 145,
#  'least': 146,
#  'going': 147,
#  'know': 148,
#  'part': 149,
#  'sometimes': 150,
#  'piece': 151,
#  'say': 152,
#  'year': 153,
#  'youll': 154,
#  'entertainment': 155,
#  'give': 156,
#  'last': 157,
#  'cinematic': 158,
#  'subject': 159,
#  'point': 160,
#  'pretty': 161,
#  'special': 162,
#  'cinema': 163,
#  'making': 164,
#  'keep': 165,
#  'bit': 166,
#  'filmmakers': 167,
#  'fascinating': 168,
#  'whole': 169,
#  'together': 170,
#  'fans': 171,
#  'away': 172,
#  'anything': 173,
#  'since': 174,
#  'style': 175,
#  'dull': 176,
#  'need': 177,
#  'manages': 178,
#  'true': 179,
#  'moving': 180,
#  'show': 181,
#  'laughs': 182,
#  'star': 183,
#  'offers': 184,
#  'always': 185,
#  'history': 186,
#  'sweet': 187,
#  'clever': 188,
#  'simply': 189,
#  'high': 190,
#  'mr': 191,
#  'direction': 192,
#  'dark': 193,
#  'instead': 194,
#  'care': 195,
#  'series': 196,
#  'charm': 197,
#  'whose': 198,
#  'actually': 199,
#  'experience': 200,
#  'art': 201,
#  'flick': 202,
#  'visual': 203,
#  'nearly': 204,
#  'silly': 205,
#  'title': 206,
#  'everything': 207,
#  'around': 208,
#  'matter': 209,
#  'predictable': 210,
#  'place': 211,
#  'video': 212,
#  'comic': 213,
#  'hes': 214,
#  'idea': 215,
#  'narrative': 216,
#  'screenplay': 217,
#  'short': 218,
#  'war': 219,
#  'goes': 220,
#  'trying': 221,
#  'done': 222,
#  'genre': 223,
#  'plays': 224,
#  'women': 225,
#  'probably': 226,
#  'familiar': 227,
#  'premise': 228,
#  'turns': 229,
#  'horror': 230,
#  'home': 231,
#  'effects': 232,
#  'becomes': 233,
#  'set': 234,
#  'although': 235,
#  'three': 236,
#  'lacks': 237,
#  'worst': 238,
#  'feeling': 239,
#  'wont': 240,
#  'feature': 241,
#  'engaging': 242,
#  'enjoyable': 243,
#  'power': 244,
#  'day': 245,
#  'smart': 246,
#  'effort': 247,
#  'ending': 248,
#  'strong': 249,
#  'charming': 250,
#  'especially': 251,
#  'half': 252,
#  'enjoy': 253,
#  'study': 254,
#  'amusing': 255,
#  'intelligent': 256,
#  'likely': 257,
#  'romance': 258,
#  'whats': 259,
#  'debut': 260,
#  'theater': 261,
#  'men': 262,
#  'lack': 263,
#  'john': 264,
#  'else': 265,
#  'certainly': 266,
#  'viewers': 267,
#  'beautiful': 268,
#  'mostly': 269,
#  'put': 270,
#  'sort': 271,
#  'version': 272,
#  'portrait': 273,
#  'boring': 274,
#  'rare': 275,
#  'easy': 276,
#  'next': 277,
#  'level': 278,
#  'become': 279,
#  'solid': 280,
#  'looking': 281,
#  'hours': 282,
#  'youve': 283,
#  'mind': 284,
#  'lives': 285,
#  'play': 286,
#  'beautifully': 287,
#  'face': 288,
#  'wit': 289,
#  'problem': 290,
#  'quirky': 291,
#  'message': 292,
#  'fine': 293,
#  'surprisingly': 294,
#  'along': 295,
#  'exercise': 296,
#  'ideas': 297,
#  'whether': 298,
#  'sure': 299,
#  'directed': 300,
#  'leave': 301,
#  'looks': 302,
#  'classic': 303,
#  'fresh': 304,
#  'obvious': 305,
#  'either': 306,
#  'energy': 307,
#  'completely': 308,
#  'modern': 309,
#  'past': 310,
#  'french': 311,
#  'interest': 312,
#  'reason': 313,
#  'powerful': 314,
#  'shot': 315,
#  'dramatic': 316,
#  'neither': 317,
#  'shows': 318,
#  'audiences': 319,
#  'filmmaking': 320,
#  'beyond': 321,
#  'fact': 322,
#  'recent': 323,
#  'culture': 324,
#  'suspense': 325,
#  'children': 326,
#  'stuff': 327,
#  'im': 328,
#  'tone': 329,
#  'didnt': 330,
#  'melodrama': 331,
#  'delivers': 332,
#  'fails': 333,
#  'everyone': 334,
#  'deeply': 335,
#  'left': 336,
#  'believe': 337,
#  'minute': 338,
#  'slow': 339,
#  'truly': 340,
#  'death': 341,
#  'tries': 342,
#  'actor': 343,
#  'black': 344,
#  'mess': 345,
#  'ends': 346,
#  'jokes': 347,
#  'book': 348,
#  'reality': 349,
#  'intriguing': 350,
#  'dumb': 351,
#  'serious': 352,
#  'small': 353,
#  'occasionally': 354,
#  'light': 355,
#  'ride': 356,
#  'spirit': 357,
#  'writerdirector': 358,
#  'sad': 359,
#  'production': 360,
#  'storytelling': 361,
#  'tv': 362,
#  'role': 363,
#  'adventure': 364,
#  'exactly': 365,
#  'formula': 366,
#  'remains': 367,
#  'terrific': 368,
#  'touching': 369,
#  'proves': 370,
#  'passion': 371,
#  'camera': 372,
#  'opera': 373,
#  'different': 374,
#  'seeing': 375,
#  'stories': 376,
#  'filmmaker': 377,
#  'girl': 378,
#  'scene': 379,
#  'must': 380,
#  'hilarious': 381,
#  'easily': 382,
#  'impossible': 383,
#  'line': 384,
#  'images': 385,
#  'project': 386,
#  'satisfying': 387,
#  'got': 388,
#  'talent': 389,
#  'already': 390,
#  'perfect': 391,
#  'personal': 392,
#  'particularly': 393,
#  'attempt': 394,
#  'sex': 395,
#  'hour': 396,
#  'gags': 397,
#  'honest': 398,
#  'turn': 399,
#  'complex': 400,
#  'psychological': 401,
#  'journey': 402,
#  'close': 403,
#  'animation': 404,
#  'difficult': 405,
#  'given': 406,
#  'simple': 407,
#  'summer': 408,
#  'falls': 409,
#  'case': 410,
#  'michael': 411,
#  'intelligence': 412,
#  'pleasure': 413,
#  'ways': 414,
#  'found': 415,
#  'comingofage': 416,
#  'head': 417,
#  'social': 418,
#  'getting': 419,
#  'political': 420,
#  'leaves': 421,
#  'earnest': 422,
#  'directors': 423,
#  'thought': 424,
#  'flat': 425,
#  'game': 426,
#  'que': 427,
#  'mystery': 428,
#  'violence': 429,
#  'uses': 430,
#  'crime': 431,
#  'sequel': 432,
#  'tell': 433,
#  'cliches': 434,
#  'live': 435,
#  'none': 436,
#  'writing': 437,
#  'written': 438,
#  'laugh': 439,
#  'spy': 440,
#  'visually': 441,
#  'memorable': 442,
#  'help': 443,
#  'gone': 444,
#  'finally': 445,
#  'told': 446,
#  'keeps': 447,
#  'side': 448,
#  'job': 449,
#  'pretentious': 450,
#  'second': 451,
#  'guys': 452,
#  'rich': 453,
#  'wrong': 454,
#  'satire': 455,
#  'cool': 456,
#  'overall': 457,
#  'days': 458,
#  'novel': 459,
#  'otherwise': 460,
#  'nature': 461,
#  'boy': 462,
#  'ones': 463,
#  'elements': 464,
#  'brilliant': 465,
#  'needs': 466,
#  'rarely': 467,
#  'lost': 468,
#  'contrived': 469,
#  'cold': 470,
#  'barely': 471,
#  'possible': 472,
#  'truth': 473,
#  'taste': 474,
#  'several': 475,
#  'wild': 476,
#  'appeal': 477,
#  'starts': 478,
#  'entirely': 479,
#  'others': 480,
#  'acted': 481,
#  'final': 482,
#  'approach': 483,
#  'imagine': 484,
#  'insight': 485,
#  'perhaps': 486,
#  'thoughtful': 487,
#  'epic': 488,
#  'act': 489,
#  'eyes': 490,
#  'excellent': 491,
#  'surprising': 492,
#  'running': 493,
#  'lead': 494,
#  'wonderful': 495,
#  'creepy': 496,
#  'tragedy': 497,
#  'warm': 498,
#  'moral': 499,
#  'adults': 500,
#  'concept': 501,
#  'soap': 502,
#  'quality': 503,
#  'four': 504,
#  'attention': 505,
#  'behind': 506,
#  'entire': 507,
#  'engrossing': 508,
#  'teen': 509,
#  'pictures': 510,
#  'parents': 511,
#  'among': 512,
#  'comedies': 513,
#  'hero': 514,
#  'result': 515,
#  'david': 516,
#  'imagination': 517,
#  'call': 518,
#  'viewer': 519,
#  'expect': 520,
#  'theyre': 521,
#  'form': 522,
#  'mood': 523,
#  'fairly': 524,
#  'scifi': 525,
#  'moment': 526,
#  'rock': 527,
#  'start': 528,
#  'nice': 529,
#  'disney': 530,
#  'perfectly': 531,
#  'la': 532,
#  'youd': 533,
#  'animated': 534,
#  'gentle': 535,
#  'quiet': 536,
#  'knows': 537,
#  'add': 538,
#  'change': 539,
#  'usual': 540,
#  'emotionally': 541,
#  'hope': 542,
#  'remarkable': 543,
#  'gorgeous': 544,
#  'witty': 545,
#  'future': 546,
#  'bring': 547,
#  'remake': 548,
#  'adaptation': 549,
#  'ive': 550,
#  'latest': 551,
#  'worse': 552,
#  'tired': 553,
#  'vision': 554,
#  'effective': 555,
#  'provides': 556,
#  'genuine': 557,
#  'beauty': 558,
#  'points': 559,
#  'begins': 560,
#  'thoroughly': 561,
#  'merely': 562,
#  'plenty': 563,
#  'sharp': 564,
#  'somewhat': 565,
#  'period': 566,
#  'maybe': 567,
#  'offer': 568,
#  'strange': 569,
#  'hit': 570,
#  'events': 571,
#  'taking': 572,
#  'thanks': 573,
#  'wonder': 574,
#  'bland': 575,
#  'deep': 576,
#  'woman': 577,
#  'ii': 578,
#  'dead': 579,
#  'tedious': 580,
#  'hell': 581,
#  'air': 582,
#  'lovely': 583,
#  'however': 584,
#  'unfortunately': 585,
#  'captures': 586,
#  'career': 587,
#  'surprise': 588,
#  'try': 589,
#  'pure': 590,
#  'important': 591,
#  'age': 592,
#  'emotions': 593,
#  'impressive': 594,
#  'definitely': 595,
#  'sit': 596,
#  'fantasy': 597,
#  'guy': 598,
#  'worthy': 599,
#  'depth': 600,
#  'clear': 601,
#  'inside': 602,
#  'lots': 603,
#  'straight': 604,
#  'utterly': 605,
#  'brings': 606,
#  'pace': 607,
#  'someone': 608,
#  'sound': 609,
#  'run': 610,
#  'view': 611,
#  'execution': 612,
#  'school': 613,
#  'sequences': 614,
#  'magic': 615,
#  'welcome': 616,
#  'throughout': 617,
#  'able': 618,
#  'subtle': 619,
#  'historical': 620,
#  'appealing': 621,
#  'scary': 622,
#  'decent': 623,
#  'ambitious': 624,
#  'suffers': 625,
#  'robert': 626,
#  'thin': 627,
#  'provocative': 628,
#  'cheap': 629,
#  'ensemble': 630,
#  'sexual': 631,
#  'process': 632,
#  'sustain': 633,
#  'female': 634,
#  'coming': 635,
#  'deserves': 636,
#  'certain': 637,
#  'girls': 638,
#  'examination': 639,
#  'read': 640,
#  'based': 641,
#  'alone': 642,
#  'relationship': 643,
#  'creative': 644,
#  'highly': 645,
#  'stupid': 646,
#  'city': 647,
#  'fire': 648,
#  'ugly': 649,
#  'lets': 650,
#  'low': 651,
#  'words': 652,
#  'question': 653,
#  'working': 654,
#  'cute': 655,
#  'potential': 656,
#  'felt': 657,
#  'exciting': 658,
#  'quickly': 659,
#  'memory': 660,
#  'impact': 661,
#  'deal': 662,
#  'hand': 663,
#  'delightful': 664,
#  'flaws': 665,
#  'playing': 666,
#  'middle': 667,
#  'issues': 668,
#  'wants': 669,
#  'cultural': 670,
#  'major': 671,
#  'upon': 672,
#  'use': 673,
#  'creates': 674,
#  'used': 675,
#  'yes': 676,
#  'across': 677,
#  'chemistry': 678,
#  'except': 679,
#  'puts': 680,
#  'cartoon': 681,
#  'tension': 682,
#  'awful': 683,
#  'single': 684,
#  'master': 685,
#  'bond': 686,
#  'rest': 687,
#  'dog': 688,
#  'actress': 689,
#  'sensitive': 690,
#  'boys': 691,
#  'filled': 692,
#  'lacking': 693,
#  'talented': 694,
#  'force': 695,
#  'winning': 696,
#  'unexpected': 697,
#  'taken': 698,
#  'sentimental': 699,
#  'poignant': 700,
#  'flawed': 701,
#  'stand': 702,
#  'class': 703,
#  'murder': 704,
#  'leads': 705,
#  'success': 706,
#  'situation': 707,
#  'touch': 708,
#  'mediocre': 709,
#  'generic': 710,
#  'loud': 711,
#  'unfunny': 712,
#  'cannot': 713,
#  'surprises': 714,
#  'eye': 715,
#  'crush': 716,
#  'grant': 717,
#  'heavy': 718,
#  'mark': 719,
#  'e': 720,
#  'hold': 721,
#  'ability': 722,
#  'sincere': 723,
#  'create': 724,
#  'relationships': 725,
#  'previous': 726,
#  'ultimate': 727,
#  'giving': 728,
#  'date': 729,
#  'slight': 730,
#  'fully': 731,
#  'slightly': 732,
#  'apart': 733,
#  'remember': 734,
#  'williams': 735,
#  'course': 736,
#  'reveals': 737,
#  'era': 738,
#  'formulaic': 739,
#  'odd': 740,
#  'supposed': 741,
#  'house': 742,
#  'cut': 743,
#  'unsettling': 744,
#  'episode': 745,
#  'convincing': 746,
#  'hardly': 747,
#  'ago': 748,
#  'country': 749,
#  'college': 750,
#  'waste': 751,
#  'seriously': 752,
#  'routine': 753,
#  'steven': 754,
#  'road': 755,
#  'extremely': 756,
#  'yearold': 757,
#  'forgettable': 758,
#  'ms': 759,
#  'es': 760,
#  'finds': 761,
#  'pleasant': 762,
#  'involved': 763,
#  'living': 764,
#  'five': 765,
#  'extreme': 766,
#  'stars': 767,
#  'george': 768,
#  'urban': 769,
#  'attempts': 770,
#  'treat': 771,
#  'joke': 772,
#  'inventive': 773,
#  'trouble': 774,
#  'largely': 775,
#  'grace': 776,
#  'twists': 777,
#  'thinking': 778,
#  'terms': 779,
#  'amount': 780,
#  'focus': 781,
#  'crazy': 782,
#  'casting': 783,
#  'arent': 784,
#  'uneven': 785,
#  'oldfashioned': 786,
#  'tragic': 787,
#  'thrills': 788,
#  'mix': 789,
#  'contemporary': 790,
#  'pop': 791,
#  'water': 792,
#  'money': 793,
#  'sets': 794,
#  'saw': 795,
#  'problems': 796,
#  'succeeds': 797,
#  'pacing': 798,
#  'masterpiece': 799,
#  'disturbing': 800,
#  'melodramatic': 801,
#  'unique': 802,
#  'happy': 803,
#  'substance': 804,
#  'happens': 805,
#  'painful': 806,
#  'indeed': 807,
#  'flicks': 808,
#  'goofy': 809,
#  'friendship': 810,
#  'business': 811,
#  'gripping': 812,
#  'intimate': 813,
#  'presents': 814,
#  'absolutely': 815,
#  'couple': 816,
#  'complete': 817,
#  'meditation': 818,
#  'involving': 819,
#  'poetry': 820,
#  'recommend': 821,
#  'successful': 822,
#  'artist': 823,
#  'watchable': 824,
#  'runs': 825,
#  'colorful': 826,
#  'themes': 827,
#  'weird': 828,
#  'promise': 829,
#  'appears': 830,
#  'considerable': 831,
#  'mildly': 832,
#  'soundtrack': 833,
#  'heaven': 834,
#  'weve': 835,
#  'drag': 836,
#  'shes': 837,
#  'missing': 838,
#  'york': 839,
#  'plain': 840,
#  'badly': 841,
#  'somehow': 842,
#  'loses': 843,
#  'called': 844,
#  'target': 845,
#  'hits': 846,
#  'british': 847,
#  'triumph': 848,
#  'imax': 849,
#  'clichs': 850,
#  'sophisticated': 851,
#  'refreshing': 852,
#  'manner': 853,
#  'parts': 854,
#  'originality': 855,
#  'played': 856,
#  'soul': 857,
#  'person': 858,
#  'couldnt': 859,
#  'equally': 860,
#  'typical': 861,
#  'politics': 862,
#  'interested': 863,
#  'mans': 864,
#  'strangely': 865,
#  'stunning': 866,
#  'niro': 867,
#  'mean': 868,
#  'pieces': 869,
#  'blend': 870,
#  'bizarre': 871,
#  'jackson': 872,
#  'wanted': 873,
#  'oscar': 874,
#  'skin': 875,
#  'share': 876,
#  'television': 877,
#  'bright': 878,
#  'eventually': 879,
#  'sentimentality': 880,
#  'twist': 881,
#  'red': 882,
#  'effect': 883,
#  'stylish': 884,
#  'gay': 885,
#  'tom': 886,
#  'evil': 887,
#  'viewing': 888,
#  'situations': 889,
#  'forced': 890,
#  'standard': 891,
#  'means': 892,
#  'el': 893,
#  'whatever': 894,
#  'alive': 895,
#  'absorbing': 896,
#  'depressing': 897,
#  'footage': 898,
#  'grief': 899,
#  'battle': 900,
#  'blue': 901,
#  'somewhere': 902,
#  'obviously': 903,
#  'general': 904,
#  'understand': 905,
#  'conflict': 906,
#  'forget': 907,
#  'frame': 908,
#  'wedding': 909,
#  'energetic': 910,
#  'miss': 911,
#  'report': 912,
#  'monster': 913,
#  'liked': 914,
#  'night': 915,
#  'terrible': 916,
#  'dry': 917,
#  'average': 918,
#  'setting': 919,
#  'fast': 920,
#  'fan': 921,
#  'questions': 922,
#  'haunting': 923,
#  'franchise': 924,
#  'created': 925,
#  'dream': 926,
#  'central': 927,
#  'loss': 928,
#  'company': 929,
#  'name': 930,
#  'derivative': 931,
#  'crafted': 932,
#  'doubt': 933,
#  'said': 934,
#  'white': 935,
#  'word': 936,
#  'poor': 937,
#  'huge': 938,
#  'peter': 939,
#  'hate': 940,
#  'refreshingly': 941,
#  'amazing': 942,
#  'fare': 943,
#  'treasure': 944,
#  'excitement': 945,
#  'allows': 946,
#  'unlike': 947,
#  'lines': 948,
#  'wellacted': 949,
#  'possibly': 950,
#  'painfully': 951,
#  'remarkably': 952,
#  'affecting': 953,
#  'warmth': 954,
#  'please': 955,
#  'holds': 956,
#  'fat': 957,
#  'brain': 958,
#  'writer': 959,
#  'fiction': 960,
#  'price': 961,
#  'weak': 962,
#  'tough': 963,
#  'heartfelt': 964,
#  'sexy': 965,
#  'places': 966,
#  'vivid': 967,
#  'break': 968,
#  'toward': 969,
#  'slapstick': 970,
#  'x': 971,
#  'deliver': 972,
#  'inspired': 973,
#  'faith': 974,
#  'atmosphere': 975,
#  'generally': 976,
#  'conventional': 977,
#  'finish': 978,
#  'clearly': 979,
#  'una': 980,
#  'match': 981,
#  'worthwhile': 982,
#  'tells': 983,
#  'japanese': 984,
#  'virtually': 985,
#  'popcorn': 986,
#  'edge': 987,
#  'let': 988,
#  'room': 989,
#  'car': 990,
#  'essentially': 991,
#  'green': 992,
#  'sitting': 993,
#  'bears': 994,
#  'superficial': 995,
#  'slice': 996,
#  'efforts': 997,
#  'kid': 998,
#  'charisma': 999,
#  ...}

# %%
def text_to_numbers(sentences, word_dict):
    data = []
    for sentence in sentences:
        sentence_data = []
        for word in sentence:
            if word in word_dict:
                word_ix = word_dict[word]#posición/ID de la palabra en el word dict
            else:
                word_ix = 0 ##posición/ID de la palabra RARE
            sentence_data.append(word_ix)
        data.append(sentence_data)
    return data

# %%
# creamos dicionario de palabras 
word_dict_rev = dict(zip(word_dict.values(), word_dict.keys()))
word_dict_rev
# Out:
# {0: 'RARE',
#  1: 'film',
#  2: 'movie',
#  3: 'one',
#  4: 'like',
#  5: 'story',
#  6: 'much',
#  7: 'even',
#  8: 'good',
#  9: 'comedy',
#  10: 'time',
#  11: 'characters',
#  12: 'films',
#  13: 'little',
#  14: 'way',
#  15: 'funny',
#  16: 'make',
#  17: 'movies',
#  18: 'enough',
#  19: 'never',
#  20: 'makes',
#  21: 'may',
#  22: 'us',
#  23: 'best',
#  24: 'work',
#  25: 'director',
#  26: 'doesnt',
#  27: 'bad',
#  28: 'love',
#  29: 'life',
#  30: 'would',
#  31: 'theres',
#  32: 'well',
#  33: 'new',
#  34: 'could',
#  35: 'something',
#  36: 'really',
#  37: 'made',
#  38: 'performances',
#  39: 'thats',
#  40: 'many',
#  41: 'drama',
#  42: 'look',
#  43: 'plot',
#  44: 'still',
#  45: 'see',
#  46: 'isnt',
#  47: 'every',
#  48: 'two',
#  49: 'nothing',
#  50: 'people',
#  51: 'better',
#  52: 'long',
#  53: 'without',
#  54: 'get',
#  55: 'action',
#  56: 'fun',
#  57: 'great',
#  58: 'though',
#  59: 'might',
#  60: 'big',
#  61: 'also',
#  62: 'cast',
#  63: 'another',
#  64: 'ever',
#  65: 'kind',
#  66: 'first',
#  67: 'audience',
#  68: 'humor',
#  69: 'sense',
#  70: 'character',
#  71: 'performance',
#  72: 'dont',
#  73: 'feels',
#  74: 'script',
#  75: 'far',
#  76: 'less',
#  77: 'seems',
#  78: 'often',
#  79: 'thing',
#  80: 'minutes',
#  81: 'real',
#  82: 'feel',
#  83: 'picture',
#  84: 'world',
#  85: 'almost',
#  86: 'tale',
#  87: 'cant',
#  88: 'yet',
#  89: 'thriller',
#  90: 'quite',
#  91: 'interesting',
#  92: 'documentary',
#  93: 'years',
#  94: 'youre',
#  95: 'screen',
#  96: 'rather',
#  97: 'entertaining',
#  98: 'end',
#  99: 'hollywood',
#  100: 'take',
#  101: 'de',
#  102: 'watching',
#  103: 'seen',
#  104: 'go',
#  105: 'ultimately',
#  106: 'full',
#  107: 'hard',
#  108: 'heart',
#  109: 'comes',
#  110: 'romantic',
#  111: 'moments',
#  112: 'despite',
#  113: 'lot',
#  114: 'american',
#  115: 'actors',
#  116: 'old',
#  117: 'acting',
#  118: 'family',
#  119: 'original',
#  120: 'right',
#  121: 'find',
#  122: 'things',
#  123: 'worth',
#  124: 'gets',
#  125: 'human',
#  126: 'takes',
#  127: 'times',
#  128: 'come',
#  129: 'back',
#  130: 'dialogue',
#  131: 'watch',
#  132: 'man',
#  133: 'scenes',
#  134: 'material',
#  135: 'young',
#  136: 'kids',
#  137: 'compelling',
#  138: 'music',
#  139: 'anyone',
#  140: 'think',
#  141: 'works',
#  142: 'seem',
#  143: 'emotional',
#  144: 'want',
#  145: 'gives',
#  146: 'least',
#  147: 'going',
#  148: 'know',
#  149: 'part',
#  150: 'sometimes',
#  151: 'piece',
#  152: 'say',
#  153: 'year',
#  154: 'youll',
#  155: 'entertainment',
#  156: 'give',
#  157: 'last',
#  158: 'cinematic',
#  159: 'subject',
#  160: 'point',
#  161: 'pretty',
#  162: 'special',
#  163: 'cinema',
#  164: 'making',
#  165: 'keep',
#  166: 'bit',
#  167: 'filmmakers',
#  168: 'fascinating',
#  169: 'whole',
#  170: 'together',
#  171: 'fans',
#  172: 'away',
#  173: 'anything',
#  174: 'since',
#  175: 'style',
#  176: 'dull',
#  177: 'need',
#  178: 'manages',
#  179: 'true',
#  180: 'moving',
#  181: 'show',
#  182: 'laughs',
#  183: 'star',
#  184: 'offers',
#  185: 'always',
#  186: 'history',
#  187: 'sweet',
#  188: 'clever',
#  189: 'simply',
#  190: 'high',
#  191: 'mr',
#  192: 'direction',
#  193: 'dark',
#  194: 'instead',
#  195: 'care',
#  196: 'series',
#  197: 'charm',
#  198: 'whose',
#  199: 'actually',
#  200: 'experience',
#  201: 'art',
#  202: 'flick',
#  203: 'visual',
#  204: 'nearly',
#  205: 'silly',
#  206: 'title',
#  207: 'everything',
#  208: 'around',
#  209: 'matter',
#  210: 'predictable',
#  211: 'place',
#  212: 'video',
#  213: 'comic',
#  214: 'hes',
#  215: 'idea',
#  216: 'narrative',
#  217: 'screenplay',
#  218: 'short',
#  219: 'war',
#  220: 'goes',
#  221: 'trying',
#  222: 'done',
#  223: 'genre',
#  224: 'plays',
#  225: 'women',
#  226: 'probably',
#  227: 'familiar',
#  228: 'premise',
#  229: 'turns',
#  230: 'horror',
#  231: 'home',
#  232: 'effects',
#  233: 'becomes',
#  234: 'set',
#  235: 'although',
#  236: 'three',
#  237: 'lacks',
#  238: 'worst',
#  239: 'feeling',
#  240: 'wont',
#  241: 'feature',
#  242: 'engaging',
#  243: 'enjoyable',
#  244: 'power',
#  245: 'day',
#  246: 'smart',
#  247: 'effort',
#  248: 'ending',
#  249: 'strong',
#  250: 'charming',
#  251: 'especially',
#  252: 'half',
#  253: 'enjoy',
#  254: 'study',
#  255: 'amusing',
#  256: 'intelligent',
#  257: 'likely',
#  258: 'romance',
#  259: 'whats',
#  260: 'debut',
#  261: 'theater',
#  262: 'men',
#  263: 'lack',
#  264: 'john',
#  265: 'else',
#  266: 'certainly',
#  267: 'viewers',
#  268: 'beautiful',
#  269: 'mostly',
#  270: 'put',
#  271: 'sort',
#  272: 'version',
#  273: 'portrait',
#  274: 'boring',
#  275: 'rare',
#  276: 'easy',
#  277: 'next',
#  278: 'level',
#  279: 'become',
#  280: 'solid',
#  281: 'looking',
#  282: 'hours',
#  283: 'youve',
#  284: 'mind',
#  285: 'lives',
#  286: 'play',
#  287: 'beautifully',
#  288: 'face',
#  289: 'wit',
#  290: 'problem',
#  291: 'quirky',
#  292: 'message',
#  293: 'fine',
#  294: 'surprisingly',
#  295: 'along',
#  296: 'exercise',
#  297: 'ideas',
#  298: 'whether',
#  299: 'sure',
#  300: 'directed',
#  301: 'leave',
#  302: 'looks',
#  303: 'classic',
#  304: 'fresh',
#  305: 'obvious',
#  306: 'either',
#  307: 'energy',
#  308: 'completely',
#  309: 'modern',
#  310: 'past',
#  311: 'french',
#  312: 'interest',
#  313: 'reason',
#  314: 'powerful',
#  315: 'shot',
#  316: 'dramatic',
#  317: 'neither',
#  318: 'shows',
#  319: 'audiences',
#  320: 'filmmaking',
#  321: 'beyond',
#  322: 'fact',
#  323: 'recent',
#  324: 'culture',
#  325: 'suspense',
#  326: 'children',
#  327: 'stuff',
#  328: 'im',
#  329: 'tone',
#  330: 'didnt',
#  331: 'melodrama',
#  332: 'delivers',
#  333: 'fails',
#  334: 'everyone',
#  335: 'deeply',
#  336: 'left',
#  337: 'believe',
#  338: 'minute',
#  339: 'slow',
#  340: 'truly',
#  341: 'death',
#  342: 'tries',
#  343: 'actor',
#  344: 'black',
#  345: 'mess',
#  346: 'ends',
#  347: 'jokes',
#  348: 'book',
#  349: 'reality',
#  350: 'intriguing',
#  351: 'dumb',
#  352: 'serious',
#  353: 'small',
#  354: 'occasionally',
#  355: 'light',
#  356: 'ride',
#  357: 'spirit',
#  358: 'writerdirector',
#  359: 'sad',
#  360: 'production',
#  361: 'storytelling',
#  362: 'tv',
#  363: 'role',
#  364: 'adventure',
#  365: 'exactly',
#  366: 'formula',
#  367: 'remains',
#  368: 'terrific',
#  369: 'touching',
#  370: 'proves',
#  371: 'passion',
#  372: 'camera',
#  373: 'opera',
#  374: 'different',
#  375: 'seeing',
#  376: 'stories',
#  377: 'filmmaker',
#  378: 'girl',
#  379: 'scene',
#  380: 'must',
#  381: 'hilarious',
#  382: 'easily',
#  383: 'impossible',
#  384: 'line',
#  385: 'images',
#  386: 'project',
#  387: 'satisfying',
#  388: 'got',
#  389: 'talent',
#  390: 'already',
#  391: 'perfect',
#  392: 'personal',
#  393: 'particularly',
#  394: 'attempt',
#  395: 'sex',
#  396: 'hour',
#  397: 'gags',
#  398: 'honest',
#  399: 'turn',
#  400: 'complex',
#  401: 'psychological',
#  402: 'journey',
#  403: 'close',
#  404: 'animation',
#  405: 'difficult',
#  406: 'given',
#  407: 'simple',
#  408: 'summer',
#  409: 'falls',
#  410: 'case',
#  411: 'michael',
#  412: 'intelligence',
#  413: 'pleasure',
#  414: 'ways',
#  415: 'found',
#  416: 'comingofage',
#  417: 'head',
#  418: 'social',
#  419: 'getting',
#  420: 'political',
#  421: 'leaves',
#  422: 'earnest',
#  423: 'directors',
#  424: 'thought',
#  425: 'flat',
#  426: 'game',
#  427: 'que',
#  428: 'mystery',
#  429: 'violence',
#  430: 'uses',
#  431: 'crime',
#  432: 'sequel',
#  433: 'tell',
#  434: 'cliches',
#  435: 'live',
#  436: 'none',
#  437: 'writing',
#  438: 'written',
#  439: 'laugh',
#  440: 'spy',
#  441: 'visually',
#  442: 'memorable',
#  443: 'help',
#  444: 'gone',
#  445: 'finally',
#  446: 'told',
#  447: 'keeps',
#  448: 'side',
#  449: 'job',
#  450: 'pretentious',
#  451: 'second',
#  452: 'guys',
#  453: 'rich',
#  454: 'wrong',
#  455: 'satire',
#  456: 'cool',
#  457: 'overall',
#  458: 'days',
#  459: 'novel',
#  460: 'otherwise',
#  461: 'nature',
#  462: 'boy',
#  463: 'ones',
#  464: 'elements',
#  465: 'brilliant',
#  466: 'needs',
#  467: 'rarely',
#  468: 'lost',
#  469: 'contrived',
#  470: 'cold',
#  471: 'barely',
#  472: 'possible',
#  473: 'truth',
#  474: 'taste',
#  475: 'several',
#  476: 'wild',
#  477: 'appeal',
#  478: 'starts',
#  479: 'entirely',
#  480: 'others',
#  481: 'acted',
#  482: 'final',
#  483: 'approach',
#  484: 'imagine',
#  485: 'insight',
#  486: 'perhaps',
#  487: 'thoughtful',
#  488: 'epic',
#  489: 'act',
#  490: 'eyes',
#  491: 'excellent',
#  492: 'surprising',
#  493: 'running',
#  494: 'lead',
#  495: 'wonderful',
#  496: 'creepy',
#  497: 'tragedy',
#  498: 'warm',
#  499: 'moral',
#  500: 'adults',
#  501: 'concept',
#  502: 'soap',
#  503: 'quality',
#  504: 'four',
#  505: 'attention',
#  506: 'behind',
#  507: 'entire',
#  508: 'engrossing',
#  509: 'teen',
#  510: 'pictures',
#  511: 'parents',
#  512: 'among',
#  513: 'comedies',
#  514: 'hero',
#  515: 'result',
#  516: 'david',
#  517: 'imagination',
#  518: 'call',
#  519: 'viewer',
#  520: 'expect',
#  521: 'theyre',
#  522: 'form',
#  523: 'mood',
#  524: 'fairly',
#  525: 'scifi',
#  526: 'moment',
#  527: 'rock',
#  528: 'start',
#  529: 'nice',
#  530: 'disney',
#  531: 'perfectly',
#  532: 'la',
#  533: 'youd',
#  534: 'animated',
#  535: 'gentle',
#  536: 'quiet',
#  537: 'knows',
#  538: 'add',
#  539: 'change',
#  540: 'usual',
#  541: 'emotionally',
#  542: 'hope',
#  543: 'remarkable',
#  544: 'gorgeous',
#  545: 'witty',
#  546: 'future',
#  547: 'bring',
#  548: 'remake',
#  549: 'adaptation',
#  550: 'ive',
#  551: 'latest',
#  552: 'worse',
#  553: 'tired',
#  554: 'vision',
#  555: 'effective',
#  556: 'provides',
#  557: 'genuine',
#  558: 'beauty',
#  559: 'points',
#  560: 'begins',
#  561: 'thoroughly',
#  562: 'merely',
#  563: 'plenty',
#  564: 'sharp',
#  565: 'somewhat',
#  566: 'period',
#  567: 'maybe',
#  568: 'offer',
#  569: 'strange',
#  570: 'hit',
#  571: 'events',
#  572: 'taking',
#  573: 'thanks',
#  574: 'wonder',
#  575: 'bland',
#  576: 'deep',
#  577: 'woman',
#  578: 'ii',
#  579: 'dead',
#  580: 'tedious',
#  581: 'hell',
#  582: 'air',
#  583: 'lovely',
#  584: 'however',
#  585: 'unfortunately',
#  586: 'captures',
#  587: 'career',
#  588: 'surprise',
#  589: 'try',
#  590: 'pure',
#  591: 'important',
#  592: 'age',
#  593: 'emotions',
#  594: 'impressive',
#  595: 'definitely',
#  596: 'sit',
#  597: 'fantasy',
#  598: 'guy',
#  599: 'worthy',
#  600: 'depth',
#  601: 'clear',
#  602: 'inside',
#  603: 'lots',
#  604: 'straight',
#  605: 'utterly',
#  606: 'brings',
#  607: 'pace',
#  608: 'someone',
#  609: 'sound',
#  610: 'run',
#  611: 'view',
#  612: 'execution',
#  613: 'school',
#  614: 'sequences',
#  615: 'magic',
#  616: 'welcome',
#  617: 'throughout',
#  618: 'able',
#  619: 'subtle',
#  620: 'historical',
#  621: 'appealing',
#  622: 'scary',
#  623: 'decent',
#  624: 'ambitious',
#  625: 'suffers',
#  626: 'robert',
#  627: 'thin',
#  628: 'provocative',
#  629: 'cheap',
#  630: 'ensemble',
#  631: 'sexual',
#  632: 'process',
#  633: 'sustain',
#  634: 'female',
#  635: 'coming',
#  636: 'deserves',
#  637: 'certain',
#  638: 'girls',
#  639: 'examination',
#  640: 'read',
#  641: 'based',
#  642: 'alone',
#  643: 'relationship',
#  644: 'creative',
#  645: 'highly',
#  646: 'stupid',
#  647: 'city',
#  648: 'fire',
#  649: 'ugly',
#  650: 'lets',
#  651: 'low',
#  652: 'words',
#  653: 'question',
#  654: 'working',
#  655: 'cute',
#  656: 'potential',
#  657: 'felt',
#  658: 'exciting',
#  659: 'quickly',
#  660: 'memory',
#  661: 'impact',
#  662: 'deal',
#  663: 'hand',
#  664: 'delightful',
#  665: 'flaws',
#  666: 'playing',
#  667: 'middle',
#  668: 'issues',
#  669: 'wants',
#  670: 'cultural',
#  671: 'major',
#  672: 'upon',
#  673: 'use',
#  674: 'creates',
#  675: 'used',
#  676: 'yes',
#  677: 'across',
#  678: 'chemistry',
#  679: 'except',
#  680: 'puts',
#  681: 'cartoon',
#  682: 'tension',
#  683: 'awful',
#  684: 'single',
#  685: 'master',
#  686: 'bond',
#  687: 'rest',
#  688: 'dog',
#  689: 'actress',
#  690: 'sensitive',
#  691: 'boys',
#  692: 'filled',
#  693: 'lacking',
#  694: 'talented',
#  695: 'force',
#  696: 'winning',
#  697: 'unexpected',
#  698: 'taken',
#  699: 'sentimental',
#  700: 'poignant',
#  701: 'flawed',
#  702: 'stand',
#  703: 'class',
#  704: 'murder',
#  705: 'leads',
#  706: 'success',
#  707: 'situation',
#  708: 'touch',
#  709: 'mediocre',
#  710: 'generic',
#  711: 'loud',
#  712: 'unfunny',
#  713: 'cannot',
#  714: 'surprises',
#  715: 'eye',
#  716: 'crush',
#  717: 'grant',
#  718: 'heavy',
#  719: 'mark',
#  720: 'e',
#  721: 'hold',
#  722: 'ability',
#  723: 'sincere',
#  724: 'create',
#  725: 'relationships',
#  726: 'previous',
#  727: 'ultimate',
#  728: 'giving',
#  729: 'date',
#  730: 'slight',
#  731: 'fully',
#  732: 'slightly',
#  733: 'apart',
#  734: 'remember',
#  735: 'williams',
#  736: 'course',
#  737: 'reveals',
#  738: 'era',
#  739: 'formulaic',
#  740: 'odd',
#  741: 'supposed',
#  742: 'house',
#  743: 'cut',
#  744: 'unsettling',
#  745: 'episode',
#  746: 'convincing',
#  747: 'hardly',
#  748: 'ago',
#  749: 'country',
#  750: 'college',
#  751: 'waste',
#  752: 'seriously',
#  753: 'routine',
#  754: 'steven',
#  755: 'road',
#  756: 'extremely',
#  757: 'yearold',
#  758: 'forgettable',
#  759: 'ms',
#  760: 'es',
#  761: 'finds',
#  762: 'pleasant',
#  763: 'involved',
#  764: 'living',
#  765: 'five',
#  766: 'extreme',
#  767: 'stars',
#  768: 'george',
#  769: 'urban',
#  770: 'attempts',
#  771: 'treat',
#  772: 'joke',
#  773: 'inventive',
#  774: 'trouble',
#  775: 'largely',
#  776: 'grace',
#  777: 'twists',
#  778: 'thinking',
#  779: 'terms',
#  780: 'amount',
#  781: 'focus',
#  782: 'crazy',
#  783: 'casting',
#  784: 'arent',
#  785: 'uneven',
#  786: 'oldfashioned',
#  787: 'tragic',
#  788: 'thrills',
#  789: 'mix',
#  790: 'contemporary',
#  791: 'pop',
#  792: 'water',
#  793: 'money',
#  794: 'sets',
#  795: 'saw',
#  796: 'problems',
#  797: 'succeeds',
#  798: 'pacing',
#  799: 'masterpiece',
#  800: 'disturbing',
#  801: 'melodramatic',
#  802: 'unique',
#  803: 'happy',
#  804: 'substance',
#  805: 'happens',
#  806: 'painful',
#  807: 'indeed',
#  808: 'flicks',
#  809: 'goofy',
#  810: 'friendship',
#  811: 'business',
#  812: 'gripping',
#  813: 'intimate',
#  814: 'presents',
#  815: 'absolutely',
#  816: 'couple',
#  817: 'complete',
#  818: 'meditation',
#  819: 'involving',
#  820: 'poetry',
#  821: 'recommend',
#  822: 'successful',
#  823: 'artist',
#  824: 'watchable',
#  825: 'runs',
#  826: 'colorful',
#  827: 'themes',
#  828: 'weird',
#  829: 'promise',
#  830: 'appears',
#  831: 'considerable',
#  832: 'mildly',
#  833: 'soundtrack',
#  834: 'heaven',
#  835: 'weve',
#  836: 'drag',
#  837: 'shes',
#  838: 'missing',
#  839: 'york',
#  840: 'plain',
#  841: 'badly',
#  842: 'somehow',
#  843: 'loses',
#  844: 'called',
#  845: 'target',
#  846: 'hits',
#  847: 'british',
#  848: 'triumph',
#  849: 'imax',
#  850: 'clichs',
#  851: 'sophisticated',
#  852: 'refreshing',
#  853: 'manner',
#  854: 'parts',
#  855: 'originality',
#  856: 'played',
#  857: 'soul',
#  858: 'person',
#  859: 'couldnt',
#  860: 'equally',
#  861: 'typical',
#  862: 'politics',
#  863: 'interested',
#  864: 'mans',
#  865: 'strangely',
#  866: 'stunning',
#  867: 'niro',
#  868: 'mean',
#  869: 'pieces',
#  870: 'blend',
#  871: 'bizarre',
#  872: 'jackson',
#  873: 'wanted',
#  874: 'oscar',
#  875: 'skin',
#  876: 'share',
#  877: 'television',
#  878: 'bright',
#  879: 'eventually',
#  880: 'sentimentality',
#  881: 'twist',
#  882: 'red',
#  883: 'effect',
#  884: 'stylish',
#  885: 'gay',
#  886: 'tom',
#  887: 'evil',
#  888: 'viewing',
#  889: 'situations',
#  890: 'forced',
#  891: 'standard',
#  892: 'means',
#  893: 'el',
#  894: 'whatever',
#  895: 'alive',
#  896: 'absorbing',
#  897: 'depressing',
#  898: 'footage',
#  899: 'grief',
#  900: 'battle',
#  901: 'blue',
#  902: 'somewhere',
#  903: 'obviously',
#  904: 'general',
#  905: 'understand',
#  906: 'conflict',
#  907: 'forget',
#  908: 'frame',
#  909: 'wedding',
#  910: 'energetic',
#  911: 'miss',
#  912: 'report',
#  913: 'monster',
#  914: 'liked',
#  915: 'night',
#  916: 'terrible',
#  917: 'dry',
#  918: 'average',
#  919: 'setting',
#  920: 'fast',
#  921: 'fan',
#  922: 'questions',
#  923: 'haunting',
#  924: 'franchise',
#  925: 'created',
#  926: 'dream',
#  927: 'central',
#  928: 'loss',
#  929: 'company',
#  930: 'name',
#  931: 'derivative',
#  932: 'crafted',
#  933: 'doubt',
#  934: 'said',
#  935: 'white',
#  936: 'word',
#  937: 'poor',
#  938: 'huge',
#  939: 'peter',
#  940: 'hate',
#  941: 'refreshingly',
#  942: 'amazing',
#  943: 'fare',
#  944: 'treasure',
#  945: 'excitement',
#  946: 'allows',
#  947: 'unlike',
#  948: 'lines',
#  949: 'wellacted',
#  950: 'possibly',
#  951: 'painfully',
#  952: 'remarkably',
#  953: 'affecting',
#  954: 'warmth',
#  955: 'please',
#  956: 'holds',
#  957: 'fat',
#  958: 'brain',
#  959: 'writer',
#  960: 'fiction',
#  961: 'price',
#  962: 'weak',
#  963: 'tough',
#  964: 'heartfelt',
#  965: 'sexy',
#  966: 'places',
#  967: 'vivid',
#  968: 'break',
#  969: 'toward',
#  970: 'slapstick',
#  971: 'x',
#  972: 'deliver',
#  973: 'inspired',
#  974: 'faith',
#  975: 'atmosphere',
#  976: 'generally',
#  977: 'conventional',
#  978: 'finish',
#  979: 'clearly',
#  980: 'una',
#  981: 'match',
#  982: 'worthwhile',
#  983: 'tells',
#  984: 'japanese',
#  985: 'virtually',
#  986: 'popcorn',
#  987: 'edge',
#  988: 'let',
#  989: 'room',
#  990: 'car',
#  991: 'essentially',
#  992: 'green',
#  993: 'sitting',
#  994: 'bears',
#  995: 'superficial',
#  996: 'slice',
#  997: 'efforts',
#  998: 'kid',
#  999: 'charisma',
#  ...}

# %%
text_data = text_to_numbers(texts, word_dict)

# %%
text_data[0]

# %%
# valid_words = ['cliche', 'love', 'hate', 'silly', 'sad']
valid_examples = [word_dict[x] for x in valid_words]

# %%
valid_examples
# Out:
# [1490, 28, 940, 205, 359]

# %%
def generate_batch_data(sentences, batch_size, window_size, method = 'skip_gram'):
    '''
        Mi perro come su comida -> (Mi, come), (perro, come), (su, come), (comida, come)
    '''
    batch_data = []
    label_data = []
    
    while len(batch_data) < batch_size:
        rand_sentences = np.random.choice(sentences)
        window_seq = [rand_sentences[max((ix-window_size),0):(ix+window_size+1)] 
                      for ix, x in enumerate(rand_sentences)]
        label_idx = [ix if ix < window_size else window_size for ix, x in enumerate(window_seq)]
        
        if method == 'skip_gram':
            batch_and_labels = [(x[y], x[:y]+x[(y+1):]) for x,y in zip(window_seq, label_idx)]
            tuple_data = [(x,y_) for x, y in batch_and_labels for y_ in y]
        else:
            raise ValueError("Método {} no implementado".format(method))
        
        batch, labels = [list(x) for x in zip(*tuple_data)]
        batch_data.extend(batch[:batch_size])
        label_data.extend(labels[:batch_size])
        
    batch_data = batch_data[:batch_size]
    label_data = label_data[:batch_size]
    
    batch_data = np.array(batch_data)
    label_data = np.transpose(np.array([label_data]))
    
    return (batch_data, label_data)

# %% [markdown]
# ## Entrenar con los Skip Grams

# %%
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1, 1))
x_inputs = tf.placeholder(tf.int32, shape =[batch_size])
y_target = tf.placeholder(tf.int32, shape = [batch_size,1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %%
embed = tf.nn.embedding_lookup(embeddings, x_inputs)

# %%
nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                              stddev=1.0/np.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# %%
# funcion de error que contrasta el ruido
loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights, biases=nce_biases,
                                    inputs=embed, labels=y_target, 
                                     num_sampled = num_sampled, num_classes=vocabulary_size))

# %%
# la distancia coseno
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings),1, keepdims=True))
normalized_embeddings = embeddings/norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
# funcion de optimizacion con radio de aprendizaje alto
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1.0).minimize(loss)

# %%
# inicializamos variables
init = tf.global_variables_initializer()
session.run(init)

# %%
loss_vect = []
loss_x_vect = []
for i in range(generations):
    batch_inputs, batch_labels = generate_batch_data(text_data, batch_size, window_size)
    feed_dict = {x_inputs: batch_inputs, y_target: batch_labels}
    session.run(optimizer, feed_dict=feed_dict)
    
    if (i+1) % print_loss_every == 0:
        loss_val = session.run(loss, feed_dict=feed_dict)
        loss_vect.append(loss_val)
        loss_x_vect.append(i+1)
        print("Iteración {}, Pérdida: ".format(i+1, loss_val))
    
    ## Validación de palabras más cercanas a las 5 seleccionadas
    if (i+1) % print_valid_every == 0:
        sim = session.run(similarity, feed_dict=feed_dict)
        for j in range(len(valid_words)):
            valid_word = word_dict_rev[valid_examples[j]]
            top_k = 10
            nearest = (-sim[j,:]).argsort()[1:top_k+1]
            log_string = "Palabras cercanas a {}:".format(valid_word)
            for k in range(top_k):
                close_word = word_dict_rev[nearest[k]]
                log_string = "%s %s, "%(log_string, close_word)
            print(log_string)
# Out:
# Iteración 500, Pérdida:
# Iteración 1000, Pérdida:
# Iteración 1500, Pérdida:
# Iteración 2000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 2500, Pérdida:
# Iteración 3000, Pérdida:
# Iteración 3500, Pérdida:
# Iteración 4000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 4500, Pérdida:
# Iteración 5000, Pérdida:
# Iteración 5500, Pérdida:
# Iteración 6000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 6500, Pérdida:
# Iteración 7000, Pérdida:
# Iteración 7500, Pérdida:
# Iteración 8000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 8500, Pérdida:
# Iteración 9000, Pérdida:
# Iteración 9500, Pérdida:
# Iteración 10000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 10500, Pérdida:
# Iteración 11000, Pérdida:
# Iteración 11500, Pérdida:
# Iteración 12000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 12500, Pérdida:
# Iteración 13000, Pérdida:
# Iteración 13500, Pérdida:
# Iteración 14000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 14500, Pérdida:
# Iteración 15000, Pérdida:
# Iteración 15500, Pérdida:
# Iteración 16000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 16500, Pérdida:
# Iteración 17000, Pérdida:
# Iteración 17500, Pérdida:
# Iteración 18000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 18500, Pérdida:
# Iteración 19000, Pérdida:
# Iteración 19500, Pérdida:
# Iteración 20000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 20500, Pérdida:
# Iteración 21000, Pérdida:
# Iteración 21500, Pérdida:
# Iteración 22000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 22500, Pérdida:
# Iteración 23000, Pérdida:
# Iteración 23500, Pérdida:
# Iteración 24000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 24500, Pérdida:
# Iteración 25000, Pérdida:
# Iteración 25500, Pérdida:
# Iteración 26000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 26500, Pérdida:
# Iteración 27000, Pérdida:
# Iteración 27500, Pérdida:
# Iteración 28000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 28500, Pérdida:
# Iteración 29000, Pérdida:
# Iteración 29500, Pérdida:
# Iteración 30000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 30500, Pérdida:
# Iteración 31000, Pérdida:
# Iteración 31500, Pérdida:
# Iteración 32000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 32500, Pérdida:
# Iteración 33000, Pérdida:
# Iteración 33500, Pérdida:
# Iteración 34000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 34500, Pérdida:
# Iteración 35000, Pérdida:
# Iteración 35500, Pérdida:
# Iteración 36000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 36500, Pérdida:
# Iteración 37000, Pérdida:
# Iteración 37500, Pérdida:
# Iteración 38000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 38500, Pérdida:
# Iteración 39000, Pérdida:
# Iteración 39500, Pérdida:
# Iteración 40000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 40500, Pérdida:
# Iteración 41000, Pérdida:
# Iteración 41500, Pérdida:
# Iteración 42000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 42500, Pérdida:
# Iteración 43000, Pérdida:
# Iteración 43500, Pérdida:
# Iteración 44000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 44500, Pérdida:
# Iteración 45000, Pérdida:
# Iteración 45500, Pérdida:
# Iteración 46000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 46500, Pérdida:
# Iteración 47000, Pérdida:
# Iteración 47500, Pérdida:
# Iteración 48000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,
# Iteración 48500, Pérdida:
# Iteración 49000, Pérdida:
# Iteración 49500, Pérdida:
# Iteración 50000, Pérdida:
# Palabras cercanas a cliche: foremost,  formulaic,  kissinger,  points,  scarcely,  decided,  sticks,  bar,  redeems,  ser,
# Palabras cercanas a love: absorbing,  flick,  blockbusters,  deep,  greek,  done,  carved,  nakata,  whimsical,  takes,
# Palabras cercanas a hate: stamina,  key,  innocuous,  earnharts,  suck,  knockout,  tuxedo,  murk,  oldschool,  tout,
# Palabras cercanas a silly: unholy,  worldclass,  juvenile,  wallop,  laundry,  comment,  spider,  mattei,  farts,  ellen,
# Palabras cercanas a sad: strikes,  dont,  unbelievable,  dish,  aptly,  unexpected,  driving,  threatening,  code,  golf,

# %%
plt.plot(loss_x_vect, loss_vect, 'k-', label = "Función de pérdidas")

# %%
texts[0]
# Out:
# 'rock destined st centurys new conan hes going make splash even greater arnold schwarzenegger jeanclaud van damme steven segal'

# %%
word_dict["rock"], word_dict["destined"], word_dict["st"], word_dict["new"], word_dict["conan"]
# Out:
# (527, 2395, 2145, 33, 6931)

# %% [markdown]
# - Si tomamos la palabra "destined" como objetivo, es la número 2457
# - Con una ventana de dimensión 1 -> 535 y 2251

# %%
M = session.run(embeddings)

# %%
M[2457]
# Out:
# array([-0.94085217,  0.3018415 , -0.20496845,  0.8809376 , -0.03157401,
#         0.09671855, -0.34895825,  0.0525012 , -0.056144  , -0.8287835 ,
#         0.38963437,  0.8470657 ,  0.21283913, -0.00479364,  0.08667302,
#         0.02141881, -0.9086523 , -0.8994634 , -0.08298612, -0.39123535,
#         0.7060497 , -0.34829712,  0.43653226, -0.73139   ,  0.9478893 ,
#         0.5507016 , -0.36344337,  0.17577004,  0.69085383,  0.09066463,
#        -0.19932747, -0.92004967,  0.62579393, -0.751065  , -0.6616819 ,
#         0.5659108 , -0.61595845, -0.1494143 ,  0.44062614, -0.7353487 ,
#        -0.93868613, -0.3512423 ,  0.5603788 , -0.88976383, -0.92388606,
#        -0.8207116 , -0.73769355, -0.8929372 ,  0.63512874, -0.21792316,
#         0.3417163 , -0.54464126, -0.51051545,  0.3117528 ,  0.61365557,
#        -0.9293215 ,  0.59742165, -0.87630224,  0.6996298 , -0.88530874,
#         0.44440293,  0.3279984 ,  0.354733  , -0.78348804, -0.35132837,
#        -0.85925174, -0.21444535, -0.40745234,  0.44598794,  0.5421214 ,
#         0.3759706 ,  0.33672333, -0.41963792,  0.5864904 ,  0.13889456,
#         0.99197865,  0.29747272,  0.89968824,  0.24063921,  0.96604824,
#        -0.07052827,  0.3953786 ,  0.01329827, -0.73071957, -0.03460526,
#         0.8462765 , -0.67968464, -0.31371808, -0.93179584, -0.9241514 ,
#         0.7246859 ,  0.87811065, -0.25367975, -0.55151296, -0.7681663 ,
#         0.68046355, -0.00266671, -0.34633708, -0.64340234, -0.6982486 ,
#        -0.49535632,  0.93596935,  0.6473856 ,  0.2936945 , -0.85611105,
#         0.40564322,  0.52491903,  0.45722008, -0.01739836,  0.12074757,
#        -0.23462725,  0.5336757 ,  0.04706025,  0.1246047 ,  0.79263234,
#         0.510231  ,  0.11264253, -0.5556779 ,  0.43715072,  0.9012475 ,
#        -0.15426159,  0.5107267 ,  0.39194036, -0.58813643, -0.6922531 ,
#         0.4374237 , -0.28600073, -0.6017933 , -0.4716642 ,  0.64272237,
#        -0.55815244,  0.75646734, -0.992563  , -0.034271  ,  0.7984445 ,
#        -0.7378323 , -0.44257474, -0.9113383 , -0.99190664, -0.48763657,
#         0.04206514,  0.40008593, -0.8120284 , -0.16788054, -0.01874733,
#         0.7897856 , -0.02171254, -0.78457904, -0.13881421, -0.34661698,
#         0.9210131 , -0.82732415, -0.46955872,  0.27796197, -0.7046652 ,
#        -0.54677224, -0.06356287,  0.67192006, -0.38103032,  0.44468832,
#        -0.81731796, -0.15643263, -0.87662077, -0.87252116, -0.3533454 ,
#         0.5505092 ,  0.8306577 , -0.7538781 ,  0.72684693,  0.7835026 ,
#        -0.6416795 , -0.16093183,  0.9137764 , -0.40396047, -0.7887051 ,
#        -0.8341677 , -0.22667384, -0.31198335, -0.12438774, -0.22363591,
#        -0.20189667,  0.8784077 , -0.6914711 , -0.3347304 , -0.43383884,
#        -0.79362845,  0.2604282 ,  0.3603754 , -0.7171116 , -0.5169313 ,
#         0.7798393 ,  0.2810452 , -0.0497272 ,  0.64219475,  0.11583233,
#         0.90057755, -0.77568626,  0.04229593, -0.33378005,  0.29501653],
#       dtype=float32)

# %%
M[535]
# Out:
# array([ 0.51949406, -0.7978132 ,  0.11353517, -0.20571327,  0.6886437 ,
#        -0.8747108 ,  0.4549539 , -0.21861792, -0.9981556 ,  0.73735404,
#         0.24903846,  0.58532214, -0.01630449,  0.43882203, -0.8782716 ,
#        -0.24567676, -0.50537133, -0.56144476,  0.86199546,  0.2472887 ,
#         0.05562735, -0.8524542 ,  0.93504214, -0.7502713 , -0.64731   ,
#         0.3115635 ,  0.96684027,  0.9348841 ,  0.48431826, -0.92469215,
#         0.8291633 , -0.49910045,  0.9344413 , -0.4682858 ,  0.88021326,
#         0.41048336,  0.54540825, -0.7191105 ,  0.24164987,  0.19714928,
#         0.77009726,  0.24259281, -0.4405005 ,  0.86296535, -0.42323732,
#        -0.5004895 , -0.9574113 ,  0.93067956,  0.76816106, -0.412009  ,
#         0.75582576, -0.5167022 , -0.4453411 , -0.6910999 , -0.5198505 ,
#         0.8617332 , -0.96271443, -0.30802345,  0.39388895,  0.8255265 ,
#        -0.38078976,  0.4923129 ,  0.6718621 , -0.03663921, -0.18266273,
#        -0.31495547,  0.65248036, -0.53200006, -0.5674851 , -0.3667338 ,
#        -0.05654025, -0.8447876 ,  0.96065545, -0.02856302, -0.9320893 ,
#        -0.7105584 , -0.8941679 , -0.3290007 , -0.3416443 , -0.28086758,
#        -0.9078481 ,  0.0890491 ,  0.85115695,  0.9195576 , -0.70748925,
#        -0.19266534, -0.5342543 ,  0.47634006,  0.21388316, -0.79628944,
#         0.5932605 , -0.18677807,  0.6359072 ,  0.3886416 , -0.20138717,
#         0.45824528, -0.12446737, -0.8413327 , -0.35493755,  0.6474855 ,
#         0.5602896 , -0.37269783,  0.11855817,  0.6763196 ,  0.9161923 ,
#         0.86610675, -0.5670223 , -0.7672298 ,  0.853251  , -0.40156198,
#        -0.9954355 , -0.58205295,  0.05913162, -0.3220787 , -0.7412417 ,
#        -0.02027106,  0.01022029,  0.17890978,  0.6180897 ,  0.7629945 ,
#         0.38859153, -0.43092346, -0.367033  ,  0.52347827,  0.23124743,
#         0.3130648 ,  0.09121084, -0.540792  ,  0.7417934 , -0.18017864,
#         0.9726362 ,  0.79073906, -0.24744987, -0.8130901 , -0.01110721,
#         0.44835448,  0.89532685, -0.77347994, -0.4331298 ,  0.12701416,
#         0.8906131 , -0.29978347, -0.8662474 , -0.5711129 , -0.97424674,
#         0.90240526, -0.6048734 ,  0.9265506 ,  0.48485827,  0.7053468 ,
#         0.03663564,  0.83220196, -0.19815421,  0.3053882 , -0.09706545,
#         0.11749196,  0.7823024 , -0.7732458 , -0.96190715,  0.48348355,
#         0.54988885, -0.5157511 ,  0.23589039, -0.58523655, -0.82483244,
#        -0.77203155, -0.08162332, -0.8512521 ,  0.505641  , -0.10705423,
#         0.9982054 ,  0.8990567 ,  0.10309243, -0.12423253,  0.21882486,
#         0.63595533, -0.36322165, -0.67479086, -0.47872066, -0.8269918 ,
#        -0.16476107,  0.40407658,  0.7606573 , -0.76002645, -0.29664683,
#         0.13238788,  0.2531984 ,  0.05528069, -0.8183017 ,  0.8502884 ,
#         0.5300846 , -0.00918818, -0.6776378 ,  0.9591329 , -0.00344706,
#         0.8771541 ,  0.32590747,  0.835052  ,  0.77575207,  0.67594504],
#       dtype=float32)
